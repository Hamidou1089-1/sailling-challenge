# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os


from wind_scenarios.sailing_physics import generate_efficiency_curve, generate_velocity_polar_plot, show_tacking_maneuver

# %%
show_tacking_maneuver()
